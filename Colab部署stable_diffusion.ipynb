# %% [markdown]
# #程序部署

# %%
#程序部署
# !pip install --upgrade fastapi==0.90.1
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
#安装视频换脸扩展
# !git clone https://github.com/Scholar01/sd-webui-mov2mov /content/stable-diffusion-webui/extensions/sd-webui-mov2mov
#安装controlnet扩展
# !git clone https://github.com/Mikubill/sd-webui-controlnet /content/stable-diffusion-webui/extensions/sd-webui-controlnet
#安装Lora扩展
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks /content/stable-diffusion-webui/extensions/sd-webui-additional-networks
#安装中文支持
# !git clone https://github.com/dtlnor/stable-diffusion-webui-localization-zh_CN /content/stable-diffusion-webui/extensions/stable-diffusion-webui-localization-zh_CN
#安装tag编辑插件
# !git clone https://github.com/ggppss2020/sd_tag_edit /content/stable-diffusion-webui/extensions/sd_tag_edit
#安装Civitai资源下载插件
# !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser /content/stable-diffusion-webui/extensions/sd-civitai-browser

#安装controlnet扩展相关常用模型
# !curl -Lo control_canny-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors
# !mv "/content/control_canny-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_depth-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors
# !mv "/content/control_depth-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_hed-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors
# !mv "/content/control_hed-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_mlsd-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors
# !mv "/content/control_mlsd-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_normal-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors
# !mv "/content/control_normal-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_openpose-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors
# !mv "/content/control_openpose-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_scribble-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors
# !mv "/content/control_scribble-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo control_seg-fp16.safetensors	https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors
# !mv "/content/control_seg-fp16.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models"
# !curl -Lo hand_pose_model.pth	https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth
# !mv "/content/hand_pose_model.pth" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose"
# !curl -Lo body_pose_model.pth	https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth
# !mv "/content/body_pose_model.pth" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/openpose"
# !curl -Lo dpt_hybrid-midas-501f0c75.pt	https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt
# !mv "/content/dpt_hybrid-midas-501f0c75.pt" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/midas"
# !curl -Lo mlsd_large_512_fp32.pth	https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth
# !mv "/content/mlsd_large_512_fp32.pth" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd"
# !curl -Lo mlsd_tiny_512_fp32.pth	https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth
# !mv "/content/mlsd_tiny_512_fp32.pth" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/mlsd"
# !curl -Lo network-bsds500.pth	https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth
# !mv "/content/network-bsds500.pth" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/hed"
# !curl -Lo upernet_global_small.pth	https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth
# !mv "/content/upernet_global_small.pth" "/content/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/uniformer"

#安装底模型ChilloutMix
# !curl -Lo ChilloutMix.safetensors https://civitai.com/api/download/models/11745
# !mv "/content/ChilloutMix.safetensors" "/content/stable-diffusion-webui/models/Stable-diffusion"
#安装840000VAE
# !curl -Lo vae-ft-mse-840000-ema-pruned.safetensors https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors
# !mv "/content/vae-ft-mse-840000-ema-pruned.safetensors" "/content/stable-diffusion-webui/models/VAE"
#安装Lora模型
# !curl -Lo koreanDollLikeness_v15.safetensors https://huggingface.co/mlgm/lora/resolve/main/koreanDollLikeness_v15.safetensors
# !mv "/content/koreanDollLikeness_v15.safetensors" "/content/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora"

# %% [markdown]
# #装载谷歌云盘

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #启动程序

# %% [markdown]
# GPU启动

# %%
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --skip-torch-cuda-test --no-half-vae --xformers --reinstall-xformers --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# CPU启动

# %%
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--use-cpu all --precision full --share --disable-safe-unpickle --skip-torch-cuda-test --no-half-vae --reinstall-xformers --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
